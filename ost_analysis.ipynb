# %%
# Calculate the score 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
df = pd.read_csv('./csv/projects.csv')
df['project_name'].count()
df['git_url'].count()
#df['project_age_in_days'].median()
df['total_number_of_commits'].median()
df['stargazers_count'].median()
df['stars_last_year'].median()
df['community_development_distribution_score'].median()
df['closed_issues'].median()
#df['issued_closed_last_year'].median()
df['reviews_per_pr'].median()
df['contributors'].median()
df['total_commits_last_year'].median()

github_projects = df['platform'] == 'github'
github_projects.value_counts()

df['platform'].value_counts()

df['project_active_checkbox'].value_counts()
df['dominating_language'].value_counts()

df = df[(df['project_active_checkbox'] == True)]


for x, y in df.items():
  print(x)

df
# Out:
# 1265
# 1143
# 460.5
# 41.0
# 11.0
# 0.29979550102249486
# 65.0
# 0.1
# 6.0
# 26.0
# True     1116
# False     149
# Name: platform, dtype: int64
# github    1116
# custom     122
# gitlab      27
# Name: platform, dtype: int64
# True     949
# False    167
# Name: project_active_checkbox, dtype: int64
# Python              400
# R                   168
# Jupyter Notebook    111
# Fortran              51
# C++                  47
# JavaScript           39
# Julia                33
# HTML                 26
# C                    25
# Java                 21
# TypeScript           20
# Ruby                 18
# MATLAB               16
# Modelica             12
# Go                    9
# Vue                   9
# C#                    8
# PHP                   5
# TeX                   5
# Makefile              4
# Scala                 4
# Shell                 3
# Kotlin                3
# Roff                  2
# GAMS                  2
# Rust                  2
# ...

# %%
df['activity'] = df['total_commits_last_year'].rank(pct=True) + df['issues_closed_last_year'].rank(pct=True) + df['days_until_last_issue_closed'].rank(pct=True) + df['project_age_in_days'].rank(pct=True)
df['community'] = df['contributors'].rank(pct=True) + df['community_development_distribution_score'].rank(pct=True) + df['reviews_per_pr'].rank(pct=True)
df['size'] = df['total_number_of_commits'].rank(pct=True) + df['contributors'].rank(pct=True) + df['closed_issues'].rank(pct=True)
df['total_score'] = df['activity'] + df['community'] + df['size']

df.sort_values('total_score', ascending=False).tail(50)

df.to_csv('csv/project_analysis.csv')
# Out:
#                                            project_name  \
# 652                                           DetecTree
# 551                                        BioSTEAM_LCA
# 247                                                draf
# 523                                           PyChEmiss
# 564                                            trashnet
# 750                                              CO2SYS
# 41                                   MPPT-Solar-Charger
# 50    A Global Inventory of Commerical-, Industrial-...
# 1151                                               OSDG
# 567                                              pycirk
# 572                                              MARIDA
# 494                                           footprint
# 231                                       Peaky Finders
# 500                                              elmada
# 970                                             saqgetr
# 496                                   Carbonfact Models
# ...

# %%
pd.options.plotting.backend = "plotly"

import plotly.express as px
fig = px.histogram(df, x="license")
fig.show()
# Out:
# <div>                            <div id="f89cc4fb-b4da-4348-a990-2dedc41350c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f89cc4fb-b4da-4348-a990-2dedc41350c5")) {                    Plotly.newPlot(                        "f89cc4fb-b4da-4348-a990-2dedc41350c5",                        [],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{
# ...

# %%
fig = px.histogram(df, x="project_age_in_days")
fig.show()
# Out:
# <div>                            <div id="87f1419e-06f1-4a59-b125-78dec0bbcf3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87f1419e-06f1-4a59-b125-78dec0bbcf3d")) {                    Plotly.newPlot(                        "87f1419e-06f1-4a59-b125-78dec0bbcf3d",                        [],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{
# ...

# %%
fig = px.histogram(df, x="rubric").update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <div>                            <div id="7738c125-abb2-4e67-bd94-fdc62abe8862" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7738c125-abb2-4e67-bd94-fdc62abe8862")) {                    Plotly.newPlot(                        "7738c125-abb2-4e67-bd94-fdc62abe8862",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"rubric=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["Photovoltaics and Solar Energy","Photovoltaics and Solar Energy","Photovoltaics and Solar Energy","Photovoltaics and Solar Energy","Photovoltaics and Solar Energy","Photovoltaics and Solar Energy","Photovoltaic
# ...

# %%
import plotly.express as px
#df = px.data.gapminder()

#fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
#	         size="pop", color="continent",
#                 hover_name="country", log_x=True, size_max=60)


#fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
#	         size="pop", color="continent",
#                 hover_name="country", log_x=True, size_max=60)

fig = px.scatter(df.query("project_active_checkbox==True"), x="contributors", y="project_age_in_days",
	         size="stargazers_count", color="rubric",
                 hover_name="project_name", log_x=True)


fig.show()
# Out:
# <div>                            <div id="654ec312-e392-43aa-a82d-c89489f2c617" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("654ec312-e392-43aa-a82d-c89489f2c617")) {                    Plotly.newPlot(                        "654ec312-e392-43aa-a82d-c89489f2c617",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>rubric=Photovoltaics and Solar Energy<br>contributors=%{x}<br>project_age_in_days=%{y}<br>stargazers_count=%{marker.size}<extra></extra>","hovertext":["pvlib-python","pvfactors","gsee","PVMismatch","rdtools","feedinlib","photovoltaic","pvcaptest","pvtrace","SolarPILOT","solar-data-tools","SolarPV-DER-simulation-utility","bifacial_radiance","BayesProcess","solcore5","solax","bifacialvf","solaR","SolarTherm","LibreSolar"
# ...

# %%
fig = px.scatter(df.query("project_active_checkbox==True"), x="contributors", y="project_age_in_days",
	         size="stargazers_count", color="license",
                 hover_name="project_name", log_x=True)


fig.show()
df
# Out:
# <div>                            <div id="2f5ec18d-6173-47a5-95ff-a4fcd6ec1f30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f5ec18d-6173-47a5-95ff-a4fcd6ec1f30")) {                    Plotly.newPlot(                        "2f5ec18d-6173-47a5-95ff-a4fcd6ec1f30",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>license=BSD-3-Clause<br>contributors=%{x}<br>project_age_in_days=%{y}<br>stargazers_count=%{marker.size}<extra></extra>","hovertext":["pvlib-python","pvfactors","gsee","PVMismatch","bifacial_radiance","dGen","OpenOA","SHARPy","NRWAL","CACTUS","MHKiT-Python","HydroPowerSimulations.jl","pygfunction","GHEtool","PyBaMM","StorageVET","System Advisor Model","REopt_Lite_API","PowerSimulations.jl","PowerSystems.jl","Balmorel",
# ...
